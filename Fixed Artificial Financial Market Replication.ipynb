# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mesa.space import MultiGrid
from mesa import Agent, Model
from mesa.time import RandomActivation
from mesa.datacollection import DataCollector

# %%
class FinancialAgent(Agent):
    """ An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.number_of_shares = 1
        self.opinion_vol= self.model.sigma + random.uniform(0, 0.1) #sigma is interactive parameter
        self.news_sensitivity= random.uniform(0, self.model.maximum_news_sensitivity) #maximum_news_sensitivity is also an interactive parameter
        self.base_propensity_to_sentiment_contagion= random.uniform(0, self.model.maximum_base_propensity_to_sentiment_contagion)
        # maximum_base_propensity_to_sentiment_contagion is also an interactive parameter
        self.propensity_to_sentiment_contagion = self.base_propensity_to_sentiment_contagion
        self.my_sentiment=0
        
    def step(self):
        #updating market sentiment
        if (self.model.returns> 0):
            if (news_arrival(FinancialMarket) > 0):
                self.propensity_to_sentiment_contagion += self.model.returns
            elif (news_arrival(FinancialMarket) < 0):
                self.propensity_to_sentiment_contagion -= self.model.returns
        elif (self.model.returns < 0):
            if (news_arrival(FinancialMarket) < 0):
                self.propensity_to_sentiment_contagion -= self.model.returns
            elif (news_arrival(FinancialMarket) > 0):
                self.propensity_to_sentiment_contagion += self.model.returns
            
        sentiment= [agent.my_sentiment for agent in self.model.grid.get_neighbors(self.pos,moore=True,include_center=False,radius=1)]
        if((self.propensity_to_sentiment_contagion* sum (sentiment)+ self.news_sensitivity *news_arrival(FinancialMarket) + np.random.normal(self.model.miu,self.opinion_vol))> 0):
          #miu is also an interactive parameter
            self.my_sentiment= 1
            self.number_of_shares += 1 #Buy
        else:
            self.my_sentiment = -1
            self.number_of_shares -=  1 #Sell

# %%
#Write code to extract DJIA Index and VIX for that batch run here
def news_arrival(model):
    if(np.random.normal(0,1) > 0):
         news_qualitative_meaning =1 
    else: 
        news_qualitative_meaning= -1
    return news_qualitative_meaning

# %%
def returns(model):
    number_of_traders= model.num_agents
    returns=sum([agent.my_sentiment for agent in model.schedule.agents]) / number_of_traders
    return returns

# %%
def logprice(model):
    try:
        log_price =model.log_price+ model.returns
    except:
         log_price= 0 + model.returns
    return log_price

# %%
class FinancialMarket(Model):
    """A model with some number of agents."""
    def __init__(self, N, width, height,sigma,maximum_news_sensitivity,maximum_base_propensity_to_sentiment_contagion,miu):
        self.running = True
        self.num_agents = N
        self.sigma=sigma
        self.maximum_news_sensitivity= maximum_news_sensitivity
        self.maximum_base_propensity_to_sentiment_contagion= maximum_base_propensity_to_sentiment_contagion
        self.miu=miu
        self.grid = MultiGrid(width, height, True)
        self.schedule = RandomActivation(self)
        self.returns=returns(self)
        # Create agents
        for i in range(self.num_agents):
            a = FinancialAgent(i, self)
            self.schedule.add(a)
            # Add the agent to a random grid cell
            x = random.randrange(self.grid.width)
            y = random.randrange(self.grid.height)
            self.grid.place_agent(a, (x, y))
            
        self.datacollector = DataCollector(
            #model_reporters={"News-Arrival": news_arrival,"Market-Clearing":market_clearing}
            model_reporters={"News-Arrival": news_arrival,"Returns":returns,"logprice":logprice}
            #agent_reporters ={"Wealth":"my_sentiment"}
        )
        
        
    def step(self):
        self.schedule.step()
        self.datacollector.collect(self)
        a=self.datacollector.get_model_vars_dataframe()
        self.returns=a.iloc[-1,1]
        self.log_price=a.iloc[-1,2]

# %%
#Run the model a certain number of times: in this case 20 times
model = FinancialMarket(50, 10, 10,0.4,0.7,0.6,0)
for i in range(20):
    model.step()

# %%
output = model.datacollector.get_model_vars_dataframe()
output
# Out:
#     News-Arrival  Returns  logprice
# 0              1     0.28      0.00
# 1              1     0.36      0.28
# 2              1     0.40      0.64
# 3             -1     0.84      1.04
# 4              1     0.44      1.88
# 5             -1     0.52      2.32
# 6             -1     0.52      2.84
# 7              1     0.56      3.36
# 8              1     0.32      3.92
# 9             -1     0.52      4.24
# 10             1     0.68      4.76
# 11            -1     0.60      5.44
# 12            -1     0.64      6.04
# 13            -1     0.64      6.68
# 14             1     0.68      7.32
# 15             1     0.68      8.00
# 16            -1     0.56      8.68
# 17             1     0.40      9.24
# 18             1     0.52      9.64
# 19             1     0.44     10.16

# %%
# server.py
#Plot agents in their grid and show their movement
from mesa.visualization.modules import CanvasGrid
from mesa.visualization.ModularVisualization import ModularServer
from mesa.visualization.modules import ChartModule
from mesa.visualization.UserParam import UserSettableParameter



n_slider1 = UserSettableParameter('slider', "Number of Agents", 100, 2, 20000, 1)
n_slider2 = UserSettableParameter('slider', "sigma", 0.4, 0, 1, 0.001)
n_slider3 = UserSettableParameter('slider', "Maximum News Sensitivity", 0.7, 0, 1, .01)
n_slider4 = UserSettableParameter('slider', "Maximum Propensity to Contagion", 0.6, 0, 1, .01)
n_slider5 = UserSettableParameter('slider', "Bias", 0, -1, 1, .01)




chart1 = ChartModule([{"Label": "Returns",
                      "Color": "Black"}],
                    data_collector_name='datacollector')
chart2= ChartModule([{"Label": "logprice",
                      "Color": "Grey"}],data_collector_name='datacollector')

def agent_portrayal(agent):
    portrayal = {"Shape": "circle",
                 "Filled": "true",
                 "Layer": 0,
                 "Color": "red",
                 "r": 0.5}
    if agent.my_sentiment > 0:
        portrayal["Color"] = "green"
    else:
        portrayal["Color"] = "red"
    return portrayal

grid = CanvasGrid(agent_portrayal, 10, 10, 500, 500)
server = ModularServer(FinancialMarket,
                       [grid,chart1,chart2],
                       "Simulated Financial Market",
                       {"N": n_slider1, "width": 10, "height": 10,"sigma":n_slider2,"maximum_news_sensitivity":n_slider3,"maximum_base_propensity_to_sentiment_contagion":n_slider4,"miu":n_slider5})

# %%
# run.py
#from server import server
server.port = 8535 # The default
server.launch()
# Out:
# Interface starting at http://127.0.0.1:8535
# Socket opened!
# {"type":"get_params"}
# {"type":"reset"}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.69}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.68}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.67}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.66}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.65}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.64}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.63}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.62}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.61}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.6}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.59}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.58}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.57}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.56}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.55}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.54}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.52}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.5}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.49}
# {"type":"get_step","step":1}
# {"type":"get_step","step":2}
# {"type":"get_step","step":3}
# {"type":"get_step","step":4}
# {"type":"get_step","step":5}
# {"type":"get_step","step":6}
# {"type":"get_step","step":7}
# {"type":"get_step","step":8}
# {"type":"get_step","step":9}
# {"type":"get_step","step":10}
# {"type":"get_step","step":11}
# {"type":"get_step","step":12}
# {"type":"get_step","step":13}
# {"type":"get_step","step":14}
# {"type":"get_step","step":15}
# {"type":"get_step","step":16}
# {"type":"get_step","step":17}
# {"type":"get_step","step":18}
# {"type":"get_step","step":19}
# {"type":"get_step","step":20}
# {"type":"get_step","step":21}
# {"type":"get_step","step":22}
# {"type":"get_step","step":23}
# {"type":"get_step","step":24}
# {"type":"get_step","step":25}
# {"type":"get_step","step":26}
# {"type":"get_step","step":27}
# {"type":"get_step","step":28}
# {"type":"get_step","step":29}
# {"type":"get_step","step":30}
# {"type":"get_step","step":31}
# {"type":"get_step","step":32}
# {"type":"get_step","step":33}
# {"type":"get_step","step":34}
# {"type":"get_step","step":35}
# {"type":"get_step","step":36}
# {"type":"get_step","step":37}
# {"type":"get_step","step":38}
# {"type":"get_step","step":39}
# {"type":"get_step","step":40}
# {"type":"get_step","step":41}
# {"type":"get_step","step":42}
# {"type":"get_step","step":43}
# {"type":"get_step","step":44}
# {"type":"get_step","step":45}
# {"type":"get_step","step":46}
# {"type":"get_step","step":47}
# {"type":"get_step","step":48}
# {"type":"get_step","step":49}
# {"type":"get_step","step":50}
# {"type":"get_step","step":51}
# {"type":"get_step","step":52}
# {"type":"get_step","step":53}
# {"type":"get_step","step":54}
# {"type":"get_step","step":55}
# {"type":"get_step","step":56}
# {"type":"get_step","step":57}
# {"type":"get_step","step":58}
# {"type":"get_step","step":59}
# {"type":"get_step","step":60}
# {"type":"get_step","step":61}
# {"type":"get_step","step":62}
# {"type":"get_step","step":63}
# {"type":"get_step","step":64}
# {"type":"get_step","step":65}
# {"type":"get_step","step":66}
# {"type":"get_step","step":67}
# {"type":"get_step","step":68}
# {"type":"get_step","step":69}
# {"type":"get_step","step":70}
# {"type":"get_step","step":71}
# {"type":"get_step","step":72}
# {"type":"get_step","step":73}
# {"type":"get_step","step":74}
# {"type":"get_step","step":75}
# {"type":"get_step","step":76}
# {"type":"get_step","step":77}
# {"type":"get_step","step":78}
# {"type":"get_step","step":79}
# {"type":"get_step","step":80}
# {"type":"get_step","step":81}
# {"type":"get_step","step":82}
# {"type":"get_step","step":83}
# {"type":"get_step","step":84}
# {"type":"get_step","step":85}
# {"type":"get_step","step":86}
# {"type":"get_step","step":87}
# {"type":"get_step","step":88}
# {"type":"get_step","step":89}
# {"type":"get_step","step":90}
# {"type":"get_step","step":91}
# {"type":"get_step","step":92}
# {"type":"get_step","step":93}
# {"type":"get_step","step":94}
# {"type":"get_step","step":95}
# {"type":"get_step","step":96}
# {"type":"get_step","step":97}
# {"type":"get_step","step":98}
# {"type":"get_step","step":99}
# {"type":"get_step","step":100}
# {"type":"get_step","step":101}
# {"type":"get_step","step":102}
# {"type":"get_step","step":103}
# {"type":"get_step","step":104}
# {"type":"get_step","step":105}
# {"type":"get_step","step":106}
# {"type":"get_step","step":107}
# {"type":"get_step","step":108}
# {"type":"get_step","step":109}
# {"type":"get_step","step":110}
# {"type":"get_step","step":111}
# {"type":"get_step","step":112}
# {"type":"get_step","step":113}
# {"type":"get_step","step":114}
# {"type":"get_step","step":115}
# {"type":"get_step","step":116}
# {"type":"get_step","step":117}
# {"type":"get_step","step":118}
# {"type":"get_step","step":119}
# {"type":"get_step","step":120}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.59}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.58}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.55}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.53}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.5}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.49}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.46}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.45}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.44}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.43}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.42}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.41}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.39}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.38}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.37}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.35}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.34}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.33}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.32}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.3}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.29}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.28}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.27}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.26}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.25}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.24}
# {"type":"submit_params","param":"maximum_base_propensity_to_sentiment_contagion","value":0.23}
# {"type":"get_step","step":121}
# {"type":"get_step","step":122}
# {"type":"get_step","step":123}
# {"type":"get_step","step":124}
# {"type":"reset"}
# {"type":"get_step","step":1}
# {"type":"get_step","step":2}
# {"type":"get_step","step":3}
# {"type":"get_step","step":4}
# {"type":"get_step","step":5}
# {"type":"get_step","step":6}
# {"type":"get_step","step":7}
# {"type":"get_step","step":8}
# {"type":"get_step","step":9}
# {"type":"get_step","step":10}
# {"type":"get_step","step":11}
# {"type":"get_step","step":12}
# {"type":"get_step","step":13}
# {"type":"get_step","step":14}
# {"type":"get_step","step":15}
# {"type":"get_step","step":16}
# {"type":"get_step","step":17}
# {"type":"get_step","step":18}
# {"type":"get_step","step":19}
# {"type":"get_step","step":20}
# {"type":"get_step","step":21}
# {"type":"get_step","step":22}
# {"type":"get_step","step":23}
# {"type":"get_step","step":24}
# {"type":"get_step","step":25}
# {"type":"get_step","step":26}
# {"type":"get_step","step":27}
# {"type":"get_step","step":28}
# {"type":"get_step","step":29}
# {"type":"get_step","step":30}
# {"type":"get_step","step":31}
# {"type":"get_step","step":32}
# {"type":"get_step","step":33}
# {"type":"get_step","step":34}
# {"type":"get_step","step":35}
# {"type":"get_step","step":36}
# {"type":"get_step","step":37}
# {"type":"get_step","step":38}
# {"type":"get_step","step":39}
# {"type":"get_step","step":40}
# {"type":"get_step","step":41}
# {"type":"get_step","step":42}
# {"type":"get_step","step":43}
# {"type":"get_step","step":44}
# {"type":"get_step","step":45}
# {"type":"get_step","step":46}
# {"type":"get_step","step":47}
# {"type":"get_step","step":48}
# {"type":"get_step","step":49}
# {"type":"get_step","step":50}
# {"type":"get_step","step":51}
# {"type":"get_step","step":52}
# {"type":"get_step","step":53}
# {"type":"get_step","step":54}
# {"type":"get_step","step":55}
# {"type":"get_step","step":56}
# {"type":"get_step","step":57}
# {"type":"get_step","step":58}
# {"type":"get_step","step":59}
# {"type":"get_step","step":60}
# {"type":"get_step","step":61}
# {"type":"get_step","step":62}
# {"type":"get_step","step":63}
# {"type":"get_step","step":64}
# {"type":"get_step","step":65}
# {"type":"get_step","step":66}
# {"type":"get_step","step":67}
# {"type":"get_step","step":68}
# {"type":"get_step","step":69}
# {"type":"get_step","step":70}
# {"type":"get_step","step":71}
# {"type":"get_step","step":72}
# {"type":"get_step","step":73}
# {"type":"get_step","step":74}
# {"type":"get_step","step":75}
# {"type":"get_step","step":76}
# {"type":"get_step","step":77}
# {"type":"get_step","step":78}
# {"type":"get_step","step":79}
# {"type":"get_step","step":80}
# {"type":"get_step","step":81}
# {"type":"get_step","step":82}
# {"type":"get_step","step":83}
# {"type":"get_step","step":84}
# {"type":"get_step","step":85}
# {"type":"get_step","step":86}
# {"type":"get_step","step":87}
# {"type":"get_step","step":88}
# {"type":"get_step","step":89}
# {"type":"get_step","step":90}
# {"type":"get_step","step":91}
# {"type":"get_step","step":92}
# {"type":"get_step","step":93}
# {"type":"get_step","step":94}
# {"type":"get_step","step":95}
# {"type":"get_step","step":96}
# {"type":"get_step","step":97}
# {"type":"get_step","step":98}
# {"type":"get_step","step":99}
# {"type":"get_step","step":100}
# {"type":"get_step","step":101}
# {"type":"get_step","step":102}
# {"type":"get_step","step":103}
# {"type":"get_step","step":104}
# {"type":"get_step","step":105}
# {"type":"get_step","step":106}
# {"type":"get_step","step":107}
# {"type":"get_step","step":108}
# {"type":"get_step","step":109}
# {"type":"get_step","step":110}
# {"type":"get_step","step":111}
# {"type":"get_step","step":112}
# {"type":"get_step","step":113}
# {"type":"get_step","step":114}
# {"type":"get_step","step":115}
# {"type":"get_step","step":116}
# {"type":"get_step","step":117}
# {"type":"get_step","step":118}
# {"type":"get_step","step":119}
# {"type":"get_step","step":120}
# {"type":"get_step","step":121}
# {"type":"get_step","step":122}
# {"type":"get_step","step":123}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.46}
# {"type":"get_step","step":124}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.43}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.39}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.36}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.34}
# {"type":"get_step","step":125}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.31}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.3}
# {"type":"get_step","step":126}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.28}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.27}
# {"type":"submit_params","param":"maximum_news_sensitivity","value":0.26}
# {"type":"get_step","step":127}
# {"type":"get_step","step":128}
# {"type":"get_step","step":129}
# {"type":"get_step","step":130}
# {"type":"get_step","step":131}
# {"type":"submit_params","param":"sigma","value":0.398}
# {"type":"get_step","step":132}
# {"type":"submit_params","param":"sigma","value":0.355}
# {"type":"submit_params","param":"sigma","value":0.326}
# {"type":"submit_params","param":"sigma","value":0.302}
# {"type":"submit_params","param":"sigma","value":0.288}
# {"type":"get_step","step":133}
# {"type":"submit_params","param":"sigma","value":0.279}
# {"type":"submit_params","param":"sigma","value":0.274}
# {"type":"submit_params","param":"sigma","value":0.269}
# {"type":"submit_params","param":"sigma","value":0.264}
# {"type":"get_step","step":134}
# {"type":"submit_params","param":"sigma","value":0.26}
# {"type":"get_step","step":135}
# {"type":"get_step","step":136}
# {"type":"get_step","step":137}
# {"type":"get_step","step":138}
# {"type":"get_step","step":139}
# {"type":"get_step","step":140}
# {"type":"get_step","step":141}
# {"type":"get_step","step":142}
# {"type":"reset"}
# {"type":"get_step","step":1}
# {"type":"get_step","step":2}
# {"type":"get_step","step":3}
# {"type":"get_step","step":4}
# {"type":"get_step","step":5}
# {"type":"get_step","step":6}
# {"type":"get_step","step":7}
# {"type":"get_step","step":8}
# {"type":"get_step","step":9}
# {"type":"get_step","step":10}
# {"type":"get_step","step":11}
# {"type":"get_step","step":12}
# {"type":"get_step","step":13}
# {"type":"get_step","step":14}
# {"type":"get_step","step":15}
# {"type":"get_step","step":16}
# {"type":"get_step","step":17}
# {"type":"get_step","step":18}
# {"type":"get_step","step":19}
# {"type":"get_step","step":20}
# {"type":"get_step","step":21}
# {"type":"get_step","step":22}
# {"type":"get_step","step":23}
# {"type":"get_step","step":24}
# {"type":"get_step","step":25}
# {"type":"get_step","step":26}
# {"type":"get_step","step":27}
# {"type":"get_step","step":28}
# {"type":"get_step","step":29}
# {"type":"get_step","step":30}
# {"type":"get_step","step":31}
# {"type":"get_step","step":32}
# {"type":"get_step","step":33}
# {"type":"get_step","step":34}
# {"type":"get_step","step":35}
# {"type":"get_step","step":36}
# {"type":"get_step","step":37}
# {"type":"get_step","step":38}
# {"type":"get_step","step":39}
# {"type":"get_step","step":40}
# {"type":"get_step","step":41}
# {"type":"get_step","step":42}
# {"type":"get_step","step":43}
# {"type":"get_step","step":44}
# {"type":"get_step","step":45}
# {"type":"get_step","step":46}
# {"type":"get_step","step":47}
# {"type":"get_step","step":48}
# {"type":"get_step","step":49}
# {"type":"get_step","step":50}
# {"type":"get_step","step":51}
# {"type":"get_step","step":52}
# {"type":"get_step","step":53}
# {"type":"get_step","step":54}
# {"type":"get_step","step":55}
# {"type":"get_step","step":56}
# {"type":"get_step","step":57}
# {"type":"get_step","step":58}
# {"type":"get_step","step":59}
# {"type":"get_step","step":60}
# {"type":"get_step","step":61}
# {"type":"get_step","step":62}
# {"type":"get_step","step":63}
# {"type":"get_step","step":64}
# {"type":"get_step","step":65}
# {"type":"get_step","step":66}
# {"type":"get_step","step":67}
# {"type":"get_step","step":68}
# {"type":"get_step","step":69}
# {"type":"get_step","step":70}
# {"type":"get_step","step":71}
# {"type":"get_step","step":72}
# {"type":"get_step","step":73}
# {"type":"get_step","step":74}
# {"type":"get_step","step":75}
# {"type":"get_step","step":76}
# {"type":"get_step","step":77}
# {"type":"get_step","step":78}
# {"type":"get_step","step":79}
# {"type":"get_step","step":80}
# {"type":"get_step","step":81}
# {"type":"get_step","step":82}
# {"type":"get_step","step":83}
# {"type":"get_step","step":84}
# {"type":"get_step","step":85}
# {"type":"get_step","step":86}
# {"type":"get_step","step":87}
# {"type":"get_step","step":88}
# {"type":"get_step","step":89}
# {"type":"get_step","step":90}
# {"type":"get_step","step":91}
# {"type":"get_step","step":92}
# {"type":"get_step","step":93}
# {"type":"get_step","step":94}
# {"type":"get_step","step":95}
# {"type":"get_step","step":96}
# {"type":"get_step","step":97}
# {"type":"get_step","step":98}
# {"type":"get_step","step":99}
# {"type":"get_step","step":100}
# {"type":"get_step","step":101}
# {"type":"get_step","step":102}
# {"type":"get_step","step":103}
# {"type":"get_step","step":104}
# {"type":"get_step","step":105}
# {"type":"get_step","step":106}
# {"type":"get_step","step":107}
# {"type":"get_step","step":108}
# {"type":"get_step","step":109}
# {"type":"get_step","step":110}
# {"type":"get_step","step":111}
# {"type":"get_step","step":112}
# {"type":"get_step","step":113}
# {"type":"get_step","step":114}
# {"type":"get_step","step":115}
# {"type":"get_step","step":116}
# {"type":"get_step","step":117}
# {"type":"get_step","step":118}
# {"type":"get_step","step":119}
# {"type":"get_step","step":120}
# {"type":"get_step","step":121}
# {"type":"get_step","step":122}
# {"type":"get_step","step":123}
# {"type":"get_step","step":124}
# {"type":"get_step","step":125}
# {"type":"get_step","step":126}
# {"type":"get_step","step":127}
# {"type":"get_step","step":128}
# {"type":"get_step","step":129}
# {"type":"get_step","step":130}
# {"type":"get_step","step":131}
# {"type":"get_step","step":132}
# {"type":"get_step","step":133}
# {"type":"get_step","step":134}
# {"type":"get_step","step":135}
# {"type":"get_step","step":136}
# {"type":"get_step","step":137}
# {"type":"get_step","step":138}
# {"type":"get_step","step":139}
# {"type":"get_step","step":140}
# {"type":"get_step","step":141}
# {"type":"get_step","step":142}
# {"type":"get_step","step":143}
# {"type":"get_step","step":144}
# {"type":"get_step","step":145}
# {"type":"get_step","step":146}
# {"type":"get_step","step":147}
# {"type":"get_step","step":148}
# {"type":"get_step","step":149}
# {"type":"get_step","step":150}
# {"type":"get_step","step":151}
# {"type":"get_step","step":152}
# {"type":"get_step","step":153}
# {"type":"get_step","step":154}
# {"type":"get_step","step":155}
# {"type":"get_step","step":156}
# {"type":"get_step","step":157}
# {"type":"get_step","step":158}
# {"type":"get_step","step":159}
# {"type":"get_step","step":160}
# {"type":"get_step","step":161}
# {"type":"get_step","step":162}
# {"type":"get_step","step":163}
# {"type":"get_step","step":164}
# {"type":"get_step","step":165}
# {"type":"get_step","step":166}
# {"type":"get_step","step":167}
# {"type":"get_step","step":168}
# {"type":"get_step","step":169}
# {"type":"get_step","step":170}
# {"type":"get_step","step":171}
# {"type":"get_step","step":172}
# {"type":"get_step","step":173}
# {"type":"get_step","step":174}
# {"type":"get_step","step":175}
# {"type":"get_step","step":176}
# {"type":"get_step","step":177}
# {"type":"get_step","step":178}
# {"type":"get_step","step":179}
# {"type":"get_step","step":180}
# {"type":"get_step","step":181}
# {"type":"get_step","step":182}
# {"type":"get_step","step":183}
# {"type":"get_step","step":184}
# {"type":"get_step","step":185}
# {"type":"get_step","step":186}
# {"type":"get_step","step":187}
# {"type":"get_step","step":188}
# {"type":"get_step","step":189}
# {"type":"get_step","step":190}
# {"type":"get_step","step":191}
# {"type":"get_step","step":192}
# {"type":"get_step","step":193}
# {"type":"get_step","step":194}
# {"type":"get_step","step":195}
# {"type":"get_step","step":196}
# {"type":"get_step","step":197}
# {"type":"get_step","step":198}
# {"type":"get_step","step":199}
# {"type":"get_step","step":200}
# {"type":"get_step","step":201}
# {"type":"get_step","step":202}
# {"type":"get_step","step":203}
# {"type":"get_step","step":204}
# {"type":"get_step","step":205}
# {"type":"get_step","step":206}
# {"type":"get_step","step":207}
# {"type":"get_step","step":208}
# {"type":"get_step","step":209}
# {"type":"get_step","step":210}
# {"type":"get_step","step":211}
# {"type":"get_step","step":212}
# {"type":"get_step","step":213}
# {"type":"get_step","step":214}
# {"type":"get_step","step":215}
# {"type":"get_step","step":216}
# {"type":"get_step","step":217}
# {"type":"get_step","step":218}
# {"type":"get_step","step":219}
# {"type":"get_step","step":220}
# {"type":"get_step","step":221}
# {"type":"get_step","step":222}
# {"type":"get_step","step":223}
# {"type":"get_step","step":224}
# {"type":"get_step","step":225}
# {"type":"get_step","step":226}
# {"type":"get_step","step":227}
# {"type":"get_step","step":228}
# {"type":"get_step","step":229}
# {"type":"get_step","step":230}
# {"type":"get_step","step":231}
# {"type":"get_step","step":232}
# {"type":"get_step","step":233}
# {"type":"get_step","step":234}
# {"type":"get_step","step":235}
# {"type":"get_step","step":236}
# {"type":"get_step","step":237}
# {"type":"get_step","step":238}
# {"type":"get_step","step":239}
# {"type":"get_step","step":240}
# {"type":"get_step","step":241}
# {"type":"get_step","step":242}
# {"type":"get_step","step":243}
# {"type":"get_step","step":244}
# {"type":"get_step","step":245}
# {"type":"get_step","step":246}
# {"type":"get_step","step":247}
# {"type":"get_step","step":248}
# {"type":"get_step","step":249}
# {"type":"get_step","step":250}
# {"type":"get_step","step":251}
# {"type":"get_step","step":252}
# {"type":"get_step","step":253}
# {"type":"get_step","step":254}
# {"type":"get_step","step":255}
# {"type":"get_step","step":256}
# {"type":"get_step","step":257}
# {"type":"get_step","step":258}
# {"type":"get_step","step":259}
# {"type":"get_step","step":260}
# {"type":"get_step","step":261}
# {"type":"get_step","step":262}
# {"type":"get_step","step":263}
# {"type":"get_step","step":264}
# {"type":"get_step","step":265}
# {"type":"get_step","step":266}
# {"type":"get_step","step":267}
# {"type":"get_step","step":268}
# {"type":"get_step","step":269}
# {"type":"get_step","step":270}
# {"type":"get_step","step":271}
# {"type":"get_step","step":272}
# {"type":"get_step","step":273}
# {"type":"get_step","step":274}
# {"type":"get_step","step":275}
# {"type":"get_step","step":276}
# {"type":"get_step","step":277}
# {"type":"get_step","step":278}
# {"type":"get_step","step":279}
# {"type":"get_step","step":280}
# {"type":"get_step","step":281}
# {"type":"get_step","step":282}
# {"type":"get_step","step":283}
# {"type":"get_step","step":284}
# {"type":"get_step","step":285}
# {"type":"get_step","step":286}
# {"type":"get_step","step":287}
# {"type":"get_step","step":288}
# {"type":"get_step","step":289}
# {"type":"get_step","step":290}
# {"type":"get_step","step":291}
# {"type":"get_step","step":292}
# {"type":"get_step","step":293}
# {"type":"get_step","step":294}
# {"type":"get_step","step":295}
# {"type":"get_step","step":296}
# {"type":"get_step","step":297}
# {"type":"get_step","step":298}
# {"type":"get_step","step":299}
# {"type":"get_step","step":300}
# {"type":"get_step","step":301}
# {"type":"get_step","step":302}
# {"type":"get_step","step":303}
# {"type":"get_step","step":304}
# {"type":"get_step","step":305}
# {"type":"get_step","step":306}
# {"type":"get_step","step":307}
# {"type":"get_step","step":308}
# {"type":"get_step","step":309}
# {"type":"get_step","step":310}
# {"type":"get_step","step":311}
# {"type":"get_step","step":312}
# {"type":"get_step","step":313}
# {"type":"get_step","step":314}
# {"type":"get_step","step":315}
# {"type":"get_step","step":316}
# {"type":"get_step","step":317}
# {"type":"get_step","step":318}
# {"type":"get_step","step":319}
# {"type":"get_step","step":320}
# {"type":"get_step","step":321}
# {"type":"get_step","step":322}
# {"type":"get_step","step":323}
# {"type":"get_step","step":324}
# {"type":"get_step","step":325}
# {"type":"get_step","step":326}
# {"type":"get_step","step":327}
# {"type":"get_step","step":328}
# {"type":"get_step","step":329}
# {"type":"get_step","step":330}
# {"type":"get_step","step":331}
# {"type":"get_step","step":332}
# {"type":"get_step","step":333}
# {"type":"get_step","step":334}
# {"type":"get_step","step":335}
# {"type":"get_step","step":336}
# {"type":"get_step","step":337}
# {"type":"get_step","step":338}
# {"type":"get_step","step":339}
# {"type":"get_step","step":340}
# {"type":"get_step","step":341}
# {"type":"get_step","step":342}
# {"type":"get_step","step":343}
# {"type":"get_step","step":344}
# {"type":"get_step","step":345}
# {"type":"get_step","step":346}
# {"type":"get_step","step":347}
# {"type":"get_step","step":348}
# {"type":"get_step","step":349}
# {"type":"get_step","step":350}
# {"type":"get_step","step":351}
# {"type":"get_step","step":352}
# {"type":"get_step","step":353}
# {"type":"get_step","step":354}
# {"type":"get_step","step":355}
# {"type":"get_step","step":356}
# {"type":"get_step","step":357}
# {"type":"get_step","step":358}
# {"type":"get_step","step":359}
# {"type":"get_step","step":360}
# {"type":"get_step","step":361}
# {"type":"get_step","step":362}
# {"type":"get_step","step":363}
# {"type":"get_step","step":364}
# {"type":"get_step","step":365}
# {"type":"get_step","step":366}
# {"type":"get_step","step":367}
# {"type":"get_step","step":368}
# {"type":"get_step","step":369}
# {"type":"get_step","step":370}
# {"type":"get_step","step":371}
# {"type":"get_step","step":372}
# {"type":"get_step","step":373}
# {"type":"get_step","step":374}
# {"type":"get_step","step":375}
# {"type":"get_step","step":376}
# {"type":"get_step","step":377}
# {"type":"get_step","step":378}
# {"type":"get_step","step":379}
# {"type":"get_step","step":380}
# {"type":"get_step","step":381}
# {"type":"get_step","step":382}
# {"type":"get_step","step":383}
# {"type":"get_step","step":384}
# {"type":"get_step","step":385}
# {"type":"get_step","step":386}
# {"type":"get_step","step":387}
# {"type":"get_step","step":388}
# {"type":"get_step","step":389}
# {"type":"get_step","step":390}
# {"type":"get_step","step":391}
# {"type":"get_step","step":392}
# {"type":"get_step","step":393}
# {"type":"get_step","step":394}
# {"type":"get_step","step":395}
# {"type":"get_step","step":396}
# {"type":"get_step","step":397}
# {"type":"get_step","step":398}
# {"type":"get_step","step":399}
# {"type":"get_step","step":400}
# {"type":"get_step","step":401}
# {"type":"get_step","step":402}
# {"type":"get_step","step":403}
# {"type":"get_step","step":404}
# {"type":"get_step","step":405}
# {"type":"get_step","step":406}
# {"type":"get_step","step":407}
# {"type":"get_step","step":408}
# {"type":"get_step","step":409}
# {"type":"get_step","step":410}
# {"type":"get_step","step":411}
# {"type":"get_step","step":412}
# {"type":"get_step","step":413}
# {"type":"get_step","step":414}
# {"type":"get_step","step":415}
# {"type":"get_step","step":416}
# {"type":"get_step","step":417}
# {"type":"get_step","step":418}
# {"type":"get_step","step":419}
# {"type":"get_step","step":420}
# {"type":"get_step","step":421}
# {"type":"get_step","step":422}
# {"type":"get_step","step":423}
# {"type":"get_step","step":424}
# {"type":"get_step","step":425}
# {"type":"get_step","step":426}
# {"type":"get_step","step":427}
# {"type":"get_step","step":428}
# {"type":"get_step","step":429}
# {"type":"get_step","step":430}
# {"type":"get_step","step":431}
# {"type":"get_step","step":432}
# {"type":"get_step","step":433}
# {"type":"get_step","step":434}
# {"type":"get_step","step":435}
# {"type":"get_step","step":436}
# {"type":"get_step","step":437}
# {"type":"get_step","step":438}
# {"type":"get_step","step":439}
# {"type":"get_step","step":440}
# {"type":"get_step","step":441}
# {"type":"get_step","step":442}
# {"type":"get_step","step":443}
# {"type":"get_step","step":444}
# {"type":"get_step","step":445}
# {"type":"get_step","step":446}
# {"type":"get_step","step":447}
# {"type":"get_step","step":448}
# {"type":"get_step","step":449}
# {"type":"get_step","step":450}
# {"type":"get_step","step":451}
# {"type":"get_step","step":452}
# {"type":"get_step","step":453}
# {"type":"get_step","step":454}
# {"type":"get_step","step":455}
# {"type":"get_step","step":456}
# {"type":"get_step","step":457}
# {"type":"get_step","step":458}
# {"type":"get_step","step":459}
# {"type":"get_step","step":460}
# {"type":"get_step","step":461}
# {"type":"get_step","step":462}
# {"type":"get_step","step":463}
# {"type":"get_step","step":464}
# {"type":"get_step","step":465}
# {"type":"get_step","step":466}
# {"type":"get_step","step":467}
# {"type":"get_step","step":468}
# {"type":"get_step","step":469}
# {"type":"get_step","step":470}
# {"type":"get_step","step":471}
# {"type":"get_step","step":472}
# {"type":"get_step","step":473}
# {"type":"get_step","step":474}
# {"type":"get_step","step":475}
# {"type":"get_step","step":476}
# {"type":"get_step","step":477}
# {"type":"get_step","step":478}
# {"type":"get_step","step":479}
# {"type":"get_step","step":480}
# {"type":"get_step","step":481}
# {"type":"get_step","step":482}
# {"type":"get_step","step":483}
# {"type":"get_step","step":484}
# {"type":"get_step","step":485}
# {"type":"get_step","step":486}
# {"type":"get_step","step":487}
# {"type":"get_step","step":488}
# {"type":"get_step","step":489}
# {"type":"get_step","step":490}
# {"type":"get_step","step":491}
# {"type":"get_step","step":492}
# {"type":"get_step","step":493}
# {"type":"get_step","step":494}
# {"type":"get_step","step":495}
# {"type":"get_step","step":496}
# {"type":"get_step","step":497}
# {"type":"get_step","step":498}
# {"type":"get_step","step":499}
# {"type":"get_step","step":500}
# {"type":"get_step","step":501}
# {"type":"get_step","step":502}
# {"type":"get_step","step":503}
# {"type":"get_step","step":504}
# {"type":"get_step","step":505}
# {"type":"get_step","step":506}
# {"type":"get_step","step":507}
# {"type":"get_step","step":508}
# {"type":"get_step","step":509}
# {"type":"get_step","step":510}
# {"type":"get_step","step":511}
# {"type":"get_step","step":512}
# {"type":"get_step","step":513}
# {"type":"get_step","step":514}
# {"type":"get_step","step":515}
# {"type":"get_step","step":516}
# {"type":"get_step","step":517}
# {"type":"get_step","step":518}
# {"type":"get_step","step":519}
# {"type":"get_step","step":520}
# {"type":"get_step","step":521}
# {"type":"get_step","step":522}
# {"type":"get_step","step":523}
# {"type":"get_step","step":524}
# {"type":"get_step","step":525}
# {"type":"get_step","step":526}
# {"type":"get_step","step":527}
# {"type":"get_step","step":528}
# {"type":"get_step","step":529}
# {"type":"get_step","step":530}
# {"type":"get_step","step":531}
# {"type":"get_step","step":532}
# {"type":"get_step","step":533}
# {"type":"get_step","step":534}
# {"type":"get_step","step":535}
# {"type":"get_step","step":536}
# {"type":"get_step","step":537}
# {"type":"get_step","step":538}
# {"type":"get_step","step":539}
# {"type":"get_step","step":540}
# {"type":"get_step","step":541}
# {"type":"get_step","step":542}
# {"type":"get_step","step":543}
# {"type":"get_step","step":544}
# {"type":"get_step","step":545}
# {"type":"get_step","step":546}
# {"type":"get_step","step":547}
# {"type":"get_step","step":548}
# {"type":"get_step","step":549}
# {"type":"get_step","step":550}
# {"type":"get_step","step":551}
# {"type":"get_step","step":552}
# {"type":"get_step","step":553}
# {"type":"get_step","step":554}
# {"type":"get_step","step":555}
# {"type":"get_step","step":556}
# {"type":"get_step","step":557}
# {"type":"get_step","step":558}
# {"type":"get_step","step":559}
# {"type":"get_step","step":560}
# {"type":"get_step","step":561}
# {"type":"get_step","step":562}
# {"type":"get_step","step":563}
# {"type":"get_step","step":564}
# {"type":"get_step","step":565}
# {"type":"get_step","step":566}
# {"type":"get_step","step":567}
# {"type":"get_step","step":568}
# {"type":"get_step","step":569}
# {"type":"get_step","step":570}
# {"type":"get_step","step":571}
# {"type":"get_step","step":572}
# {"type":"get_step","step":573}
# {"type":"get_step","step":574}
# {"type":"get_step","step":575}
# {"type":"get_step","step":576}
# {"type":"get_step","step":577}
# {"type":"get_step","step":578}
# {"type":"get_step","step":579}
# {"type":"get_step","step":580}
# {"type":"get_step","step":581}
# {"type":"get_step","step":582}
# {"type":"get_step","step":583}
# {"type":"get_step","step":584}
# {"type":"get_step","step":585}
# {"type":"get_step","step":586}
# {"type":"get_step","step":587}
# {"type":"get_step","step":588}
# {"type":"get_step","step":589}
# {"type":"get_step","step":590}
# {"type":"get_step","step":591}
# {"type":"get_step","step":592}
# {"type":"get_step","step":593}
# {"type":"get_step","step":594}
# {"type":"get_step","step":595}
# {"type":"get_step","step":596}
# {"type":"get_step","step":597}
# {"type":"get_step","step":598}
# {"type":"get_step","step":599}
# {"type":"get_step","step":600}
# {"type":"get_step","step":601}
# {"type":"get_step","step":602}
# {"type":"get_step","step":603}
# {"type":"get_step","step":604}
# {"type":"get_step","step":605}
# {"type":"get_step","step":606}
# {"type":"get_step","step":607}
# {"type":"get_step","step":608}
# {"type":"get_step","step":609}
# {"type":"get_step","step":610}
# {"type":"get_step","step":611}
# {"type":"get_step","step":612}
# {"type":"get_step","step":613}
# {"type":"get_step","step":614}
# {"type":"get_step","step":615}
# {"type":"get_step","step":616}
# {"type":"get_step","step":617}
# {"type":"get_step","step":618}
# {"type":"get_step","step":619}
# {"type":"get_step","step":620}
# {"type":"get_step","step":621}
# {"type":"get_step","step":622}
# {"type":"get_step","step":623}
# {"type":"get_step","step":624}
# {"type":"get_step","step":625}
# {"type":"get_step","step":626}
# {"type":"get_step","step":627}
# {"type":"get_step","step":628}
# {"type":"get_step","step":629}
# {"type":"get_step","step":630}
# {"type":"get_step","step":631}
# {"type":"get_step","step":632}
# {"type":"get_step","step":633}
# {"type":"get_step","step":634}
# {"type":"get_step","step":635}
# {"type":"get_step","step":636}
# {"type":"get_step","step":637}
# {"type":"get_step","step":638}
# {"type":"get_step","step":639}
# {"type":"get_step","step":640}
# {"type":"get_step","step":641}
# {"type":"get_step","step":642}
# {"type":"get_step","step":643}
# {"type":"get_step","step":644}
# {"type":"get_step","step":645}
# {"type":"get_step","step":646}
# {"type":"get_step","step":647}
# {"type":"get_step","step":648}
# {"type":"get_step","step":649}
# {"type":"get_step","step":650}
# {"type":"get_step","step":651}
# {"type":"get_step","step":652}
# {"type":"get_step","step":653}
# {"type":"get_step","step":654}
# {"type":"get_step","step":655}
# {"type":"get_step","step":656}
# {"type":"get_step","step":657}
# {"type":"get_step","step":658}
# {"type":"get_step","step":659}
# {"type":"get_step","step":660}
# {"type":"get_step","step":661}
# {"type":"get_step","step":662}
# {"type":"get_step","step":663}
# {"type":"get_step","step":664}
# {"type":"get_step","step":665}
# {"type":"get_step","step":666}
# {"type":"get_step","step":667}
# {"type":"get_step","step":668}
# {"type":"get_step","step":669}
# {"type":"get_step","step":670}
# {"type":"get_step","step":671}
# {"type":"get_step","step":672}
# {"type":"get_step","step":673}
# {"type":"get_step","step":674}
# {"type":"get_step","step":675}
# {"type":"get_step","step":676}
# {"type":"get_step","step":677}
# {"type":"get_step","step":678}
# {"type":"get_step","step":679}
# {"type":"get_step","step":680}
# {"type":"get_step","step":681}
# {"type":"get_step","step":682}
# {"type":"get_step","step":683}
# {"type":"get_step","step":684}
# {"type":"get_step","step":685}
# {"type":"get_step","step":686}
# {"type":"get_step","step":687}
# {"type":"get_step","step":688}
# {"type":"get_step","step":689}
# {"type":"get_step","step":690}
# {"type":"get_step","step":691}
# {"type":"get_step","step":692}
# {"type":"get_step","step":693}
# {"type":"get_step","step":694}
# {"type":"get_step","step":695}
# {"type":"get_step","step":696}
# {"type":"get_step","step":697}
# {"type":"get_step","step":698}
# {"type":"get_step","step":699}
# {"type":"get_step","step":700}
# {"type":"get_step","step":701}
# {"type":"get_step","step":702}
# {"type":"get_step","step":703}
# {"type":"get_step","step":704}
# {"type":"get_step","step":705}
# {"type":"get_step","step":706}
# {"type":"get_step","step":707}
# {"type":"get_step","step":708}
# {"type":"get_step","step":709}
# {"type":"get_step","step":710}
# {"type":"get_step","step":711}
# {"type":"get_step","step":712}
# {"type":"get_step","step":713}
# {"type":"get_step","step":714}
# {"type":"get_step","step":715}
# {"type":"get_step","step":716}
# {"type":"get_step","step":717}
# {"type":"get_step","step":718}
# {"type":"get_step","step":719}
# {"type":"get_step","step":720}
# {"type":"get_step","step":721}
# {"type":"get_step","step":722}
# {"type":"get_step","step":723}
# {"type":"get_step","step":724}
# {"type":"get_step","step":725}
# {"type":"get_step","step":726}
# {"type":"get_step","step":727}
# {"type":"get_step","step":728}
# {"type":"get_step","step":729}
# {"type":"get_step","step":730}
# {"type":"get_step","step":731}
# {"type":"get_step","step":732}
# {"type":"get_step","step":733}
# {"type":"get_step","step":734}
# {"type":"get_step","step":735}
# {"type":"get_step","step":736}
# {"type":"get_step","step":737}
# {"type":"get_step","step":738}
# {"type":"get_step","step":739}
# {"type":"get_step","step":740}
# {"type":"get_step","step":741}
# {"type":"get_step","step":742}
# {"type":"get_step","step":743}
# {"type":"get_step","step":744}
# {"type":"get_step","step":745}
# {"type":"get_step","step":746}
# {"type":"get_step","step":747}
# {"type":"get_step","step":748}
# {"type":"get_step","step":749}
# {"type":"get_step","step":750}
# {"type":"get_step","step":751}
# {"type":"get_step","step":752}
# {"type":"get_step","step":753}
# {"type":"get_step","step":754}
# {"type":"get_step","step":755}
# {"type":"get_step","step":756}
# {"type":"get_step","step":757}
# {"type":"get_step","step":758}
# {"type":"get_step","step":759}
# {"type":"get_step","step":760}
# {"type":"get_step","step":761}
# {"type":"get_step","step":762}
# {"type":"get_step","step":763}
# {"type":"get_step","step":764}
# {"type":"get_step","step":765}
# {"type":"get_step","step":766}
# {"type":"get_step","step":767}
# {"type":"get_step","step":768}
# {"type":"get_step","step":769}
# {"type":"get_step","step":770}
# {"type":"get_step","step":771}
# {"type":"get_step","step":772}
# {"type":"get_step","step":773}
# {"type":"get_step","step":774}
# {"type":"get_step","step":775}
# {"type":"get_step","step":776}
# {"type":"get_step","step":777}
# {"type":"get_step","step":778}
# {"type":"get_step","step":779}
# {"type":"get_step","step":780}
# {"type":"get_step","step":781}
# {"type":"get_step","step":782}
# {"type":"get_step","step":783}
# {"type":"get_step","step":784}
# {"type":"get_step","step":785}
# {"type":"get_step","step":786}
# {"type":"get_step","step":787}
# {"type":"get_step","step":788}
# {"type":"get_step","step":789}
# {"type":"get_step","step":790}
# {"type":"get_step","step":791}
# {"type":"get_step","step":792}
# {"type":"get_step","step":793}
# {"type":"get_step","step":794}
# {"type":"get_step","step":795}
# {"type":"get_step","step":796}
# {"type":"get_step","step":797}
# {"type":"get_step","step":798}
# {"type":"get_step","step":799}
# {"type":"get_step","step":800}
# {"type":"get_step","step":801}
# {"type":"get_step","step":802}
# {"type":"get_step","step":803}
# {"type":"get_step","step":804}
# {"type":"get_step","step":805}
# {"type":"get_step","step":806}
# {"type":"get_step","step":807}
# {"type":"get_step","step":808}
# {"type":"get_step","step":809}
# {"type":"get_step","step":810}
# {"type":"get_step","step":811}
# {"type":"get_step","step":812}
# {"type":"get_step","step":813}
# {"type":"get_step","step":814}
# {"type":"get_step","step":815}
# {"type":"get_step","step":816}
# {"type":"get_step","step":817}
# {"type":"get_step","step":818}
# {"type":"get_step","step":819}
# {"type":"get_step","step":820}
# {"type":"get_step","step":821}
# {"type":"get_step","step":822}
# {"type":"get_step","step":823}
# {"type":"get_step","step":824}
# {"type":"get_step","step":825}
# {"type":"get_step","step":826}
# {"type":"get_step","step":827}
# {"type":"get_step","step":828}
# {"type":"get_step","step":829}
# {"type":"get_step","step":830}
# {"type":"get_step","step":831}
# {"type":"get_step","step":832}
# {"type":"get_step","step":833}
# {"type":"get_step","step":834}
# {"type":"get_step","step":835}
# {"type":"get_step","step":836}
# {"type":"get_step","step":837}
# {"type":"get_step","step":838}
# {"type":"get_step","step":839}
# {"type":"get_step","step":840}
# {"type":"get_step","step":841}
# {"type":"get_step","step":842}
# {"type":"get_step","step":843}
# {"type":"get_step","step":844}
# {"type":"get_step","step":845}
# {"type":"get_step","step":846}
# {"type":"get_step","step":847}
# {"type":"get_step","step":848}
# {"type":"get_step","step":849}
# {"type":"get_step","step":850}
# {"type":"get_step","step":851}
# {"type":"get_step","step":852}
# {"type":"get_step","step":853}
# {"type":"get_step","step":854}
# {"type":"get_step","step":855}
# {"type":"get_step","step":856}
# {"type":"get_step","step":857}
# {"type":"get_step","step":858}
# {"type":"get_step","step":859}
# {"type":"get_step","step":860}
# {"type":"get_step","step":861}
# {"type":"get_step","step":862}
# {"type":"get_step","step":863}
# {"type":"get_step","step":864}
# {"type":"get_step","step":865}
# {"type":"get_step","step":866}
# {"type":"get_step","step":867}
# {"type":"get_step","step":868}
# {"type":"get_step","step":869}
# {"type":"get_step","step":870}
# {"type":"get_step","step":871}
# {"type":"get_step","step":872}
# {"type":"get_step","step":873}
# {"type":"get_step","step":874}
# {"type":"get_step","step":875}
# {"type":"get_step","step":876}
# {"type":"get_step","step":877}
# {"type":"get_step","step":878}
# {"type":"get_step","step":879}
# {"type":"get_step","step":880}
# {"type":"get_step","step":881}
# {"type":"get_step","step":882}
# {"type":"get_step","step":883}
# {"type":"get_step","step":884}
# {"type":"get_step","step":885}
# {"type":"get_step","step":886}
# {"type":"get_step","step":887}
# {"type":"get_step","step":888}
# {"type":"get_step","step":889}
# {"type":"get_step","step":890}
# {"type":"get_step","step":891}
# {"type":"get_step","step":892}
# {"type":"get_step","step":893}
# {"type":"get_step","step":894}
# {"type":"get_step","step":895}
# {"type":"get_step","step":896}
# {"type":"get_step","step":897}
# {"type":"get_step","step":898}
# {"type":"get_step","step":899}
# {"type":"get_step","step":900}
# {"type":"get_step","step":901}
# {"type":"get_step","step":902}
# {"type":"get_step","step":903}
# {"type":"get_step","step":904}
# {"type":"get_step","step":905}
# {"type":"get_step","step":906}
# {"type":"get_step","step":907}
# {"type":"get_step","step":908}
# {"type":"get_step","step":909}
# {"type":"get_step","step":910}
# {"type":"get_step","step":911}
# {"type":"get_step","step":912}
# {"type":"get_step","step":913}
# {"type":"get_step","step":914}
# {"type":"get_step","step":915}
# {"type":"get_step","step":916}
# {"type":"get_step","step":917}
# {"type":"get_step","step":918}
# {"type":"get_step","step":919}
# {"type":"get_step","step":920}
# {"type":"get_step","step":921}
# {"type":"get_step","step":922}
# {"type":"get_step","step":923}
# {"type":"get_step","step":924}
# {"type":"get_step","step":925}
# {"type":"get_step","step":926}
# {"type":"get_step","step":927}
# {"type":"get_step","step":928}
# {"type":"get_step","step":929}
# {"type":"get_step","step":930}
# {"type":"get_step","step":931}
# {"type":"get_step","step":932}
# {"type":"get_step","step":933}
# {"type":"get_step","step":934}
# {"type":"get_step","step":935}
# {"type":"get_step","step":936}
# {"type":"get_step","step":937}
# {"type":"get_step","step":938}
# {"type":"get_step","step":939}
# {"type":"get_step","step":940}
# {"type":"get_step","step":941}
# {"type":"get_step","step":942}
# {"type":"get_step","step":943}
# {"type":"get_step","step":944}
# {"type":"get_step","step":945}
# {"type":"get_step","step":946}
# {"type":"get_step","step":947}
# {"type":"get_step","step":948}
# {"type":"get_step","step":949}
# {"type":"get_step","step":950}
# {"type":"get_step","step":951}
# {"type":"get_step","step":952}
# {"type":"get_step","step":953}
# {"type":"get_step","step":954}
# {"type":"get_step","step":955}
# {"type":"get_step","step":956}
# {"type":"get_step","step":957}
# {"type":"get_step","step":958}
# {"type":"get_step","step":959}
# {"type":"get_step","step":960}
# {"type":"get_step","step":961}
# {"type":"get_step","step":962}
# {"type":"get_step","step":963}
# {"type":"get_step","step":964}
# {"type":"get_step","step":965}
# {"type":"get_step","step":966}
# {"type":"get_step","step":967}
# {"type":"get_step","step":968}
# {"type":"get_step","step":969}
# {"type":"get_step","step":970}
# {"type":"get_step","step":971}
# {"type":"get_step","step":972}
# {"type":"get_step","step":973}
# {"type":"get_step","step":974}
# {"type":"get_step","step":975}
# {"type":"get_step","step":976}
# {"type":"get_step","step":977}
# {"type":"get_step","step":978}
# {"type":"get_step","step":979}
# {"type":"get_step","step":980}
# {"type":"get_step","step":981}
# {"type":"get_step","step":982}
# {"type":"get_step","step":983}
# {"type":"get_step","step":984}
# {"type":"get_step","step":985}
# {"type":"get_step","step":986}
# {"type":"get_step","step":987}
# {"type":"get_step","step":988}
# {"type":"get_step","step":989}
# {"type":"get_step","step":990}
# {"type":"get_step","step":991}
# {"type":"get_step","step":992}
# {"type":"get_step","step":993}
# {"type":"get_step","step":994}
# {"type":"get_step","step":995}
# {"type":"get_step","step":996}
# {"type":"get_step","step":997}
# {"type":"get_step","step":998}
# {"type":"get_step","step":999}
# {"type":"get_step","step":1000}
# {"type":"get_step","step":1001}
# {"type":"get_step","step":1002}
# {"type":"get_step","step":1003}
# {"type":"get_step","step":1004}
# {"type":"get_step","step":1005}
# {"type":"get_step","step":1006}
# {"type":"get_step","step":1007}
# {"type":"get_step","step":1008}
# {"type":"get_step","step":1009}
# {"type":"get_step","step":1010}
# {"type":"get_step","step":1011}
# {"type":"get_step","step":1012}
# {"type":"get_step","step":1013}
# {"type":"get_step","step":1014}
# {"type":"get_step","step":1015}
# {"type":"get_step","step":1016}
# {"type":"get_step","step":1017}
# {"type":"get_step","step":1018}
# {"type":"get_step","step":1019}
# {"type":"get_step","step":1020}
# {"type":"get_step","step":1021}
# {"type":"get_step","step":1022}
# {"type":"get_step","step":1023}
# {"type":"get_step","step":1024}
# {"type":"get_step","step":1025}
# {"type":"get_step","step":1026}
# {"type":"get_step","step":1027}
# {"type":"get_step","step":1028}
# {"type":"get_step","step":1029}
# {"type":"get_step","step":1030}
# {"type":"get_step","step":1031}
# {"type":"get_step","step":1032}
# {"type":"get_step","step":1033}
# {"type":"get_step","step":1034}
# {"type":"get_step","step":1035}
# {"type":"get_step","step":1036}
# {"type":"get_step","step":1037}
# {"type":"get_step","step":1038}
# {"type":"get_step","step":1039}
# {"type":"get_step","step":1040}
# {"type":"get_step","step":1041}
# {"type":"get_step","step":1042}
# {"type":"get_step","step":1043}
# {"type":"get_step","step":1044}
# {"type":"get_step","step":1045}
# {"type":"get_step","step":1046}
# {"type":"get_step","step":1047}
# {"type":"get_step","step":1048}
# {"type":"get_step","step":1049}
# {"type":"get_step","step":1050}
# {"type":"get_step","step":1051}
# {"type":"get_step","step":1052}
# {"type":"get_step","step":1053}
# {"type":"get_step","step":1054}
# {"type":"get_step","step":1055}
# {"type":"get_step","step":1056}
# {"type":"get_step","step":1057}
# {"type":"get_step","step":1058}
# {"type":"get_step","step":1059}
# {"type":"get_step","step":1060}
# {"type":"get_step","step":1061}
# {"type":"get_step","step":1062}
# {"type":"get_step","step":1063}
# {"type":"get_step","step":1064}
# {"type":"get_step","step":1065}
# {"type":"get_step","step":1066}
# {"type":"get_step","step":1067}
# {"type":"get_step","step":1068}
# {"type":"get_step","step":1069}
# {"type":"get_step","step":1070}
# {"type":"get_step","step":1071}
# {"type":"get_step","step":1072}
# {"type":"get_step","step":1073}
# {"type":"get_step","step":1074}
# {"type":"get_step","step":1075}
# {"type":"get_step","step":1076}
# {"type":"get_step","step":1077}
# {"type":"get_step","step":1078}
# {"type":"get_step","step":1079}
# {"type":"get_step","step":1080}
# {"type":"get_step","step":1081}
# {"type":"get_step","step":1082}
# {"type":"get_step","step":1083}
# {"type":"get_step","step":1084}
# {"type":"get_step","step":1085}
# {"type":"get_step","step":1086}
# {"type":"get_step","step":1087}
# {"type":"get_step","step":1088}
# {"type":"get_step","step":1089}
# {"type":"get_step","step":1090}
# {"type":"get_step","step":1091}
# {"type":"get_step","step":1092}
# {"type":"get_step","step":1093}
# {"type":"get_step","step":1094}
# {"type":"get_step","step":1095}
# {"type":"get_step","step":1096}
# {"type":"get_step","step":1097}
# {"type":"get_step","step":1098}
# {"type":"get_step","step":1099}
# {"type":"get_step","step":1100}
# {"type":"get_step","step":1101}
# {"type":"get_step","step":1102}
# {"type":"get_step","step":1103}
# {"type":"get_step","step":1104}
# {"type":"get_step","step":1105}
# {"type":"get_step","step":1106}
# {"type":"get_step","step":1107}
# {"type":"get_step","step":1108}
# {"type":"get_step","step":1109}
# {"type":"get_step","step":1110}
# {"type":"get_step","step":1111}
# {"type":"get_step","step":1112}
# {"type":"get_step","step":1113}
# {"type":"get_step","step":1114}
# {"type":"get_step","step":1115}
# {"type":"get_step","step":1116}
# {"type":"get_step","step":1117}
# {"type":"get_step","step":1118}
# {"type":"get_step","step":1119}
# {"type":"get_step","step":1120}
# {"type":"get_step","step":1121}
# {"type":"get_step","step":1122}
# {"type":"get_step","step":1123}
# {"type":"get_step","step":1124}
# {"type":"get_step","step":1125}
# {"type":"get_step","step":1126}
# {"type":"get_step","step":1127}
# {"type":"get_step","step":1128}
# {"type":"get_step","step":1129}
# {"type":"get_step","step":1130}
# {"type":"get_step","step":1131}
# {"type":"get_step","step":1132}
# {"type":"get_step","step":1133}
# {"type":"get_step","step":1134}
# {"type":"get_step","step":1135}
# {"type":"get_step","step":1136}
# {"type":"get_step","step":1137}
# {"type":"get_step","step":1138}
# {"type":"get_step","step":1139}
# {"type":"get_step","step":1140}
# {"type":"get_step","step":1141}
# {"type":"get_step","step":1142}
# {"type":"get_step","step":1143}
# {"type":"get_step","step":1144}
# {"type":"get_step","step":1145}
# {"type":"get_step","step":1146}
# {"type":"get_step","step":1147}
# {"type":"get_step","step":1148}
# {"type":"get_step","step":1149}
# {"type":"get_step","step":1150}
# {"type":"get_step","step":1151}
# {"type":"get_step","step":1152}
# {"type":"get_step","step":1153}
# {"type":"get_step","step":1154}
# {"type":"get_step","step":1155}
# {"type":"get_step","step":1156}
# {"type":"get_step","step":1157}
# {"type":"get_step","step":1158}
# {"type":"get_step","step":1159}
# {"type":"get_step","step":1160}
# {"type":"get_step","step":1161}
# {"type":"get_step","step":1162}
# {"type":"get_step","step":1163}
# {"type":"get_step","step":1164}
# {"type":"get_step","step":1165}
# {"type":"get_step","step":1166}
# {"type":"get_step","step":1167}
# {"type":"get_step","step":1168}
# {"type":"get_step","step":1169}
# {"type":"get_step","step":1170}
# {"type":"get_step","step":1171}
# {"type":"get_step","step":1172}
# {"type":"get_step","step":1173}
# {"type":"get_step","step":1174}
# {"type":"get_step","step":1175}
# {"type":"get_step","step":1176}
# {"type":"get_step","step":1177}
# {"type":"get_step","step":1178}
# {"type":"get_step","step":1179}
# {"type":"get_step","step":1180}
# {"type":"get_step","step":1181}
# {"type":"get_step","step":1182}
# {"type":"get_step","step":1183}
# {"type":"get_step","step":1184}
# {"type":"get_step","step":1185}
# {"type":"get_step","step":1186}
# {"type":"get_step","step":1187}
# {"type":"get_step","step":1188}
# {"type":"get_step","step":1189}
# {"type":"get_step","step":1190}
# {"type":"get_step","step":1191}
# {"type":"get_step","step":1192}
# {"type":"get_step","step":1193}
# {"type":"get_step","step":1194}
# {"type":"get_step","step":1195}
# {"type":"get_step","step":1196}
# {"type":"get_step","step":1197}
# {"type":"get_step","step":1198}
# {"type":"get_step","step":1199}
# {"type":"get_step","step":1200}
# {"type":"get_step","step":1201}
# {"type":"get_step","step":1202}
# {"type":"get_step","step":1203}
# {"type":"get_step","step":1204}
# {"type":"get_step","step":1205}
# {"type":"get_step","step":1206}
# {"type":"get_step","step":1207}
# {"type":"get_step","step":1208}
# {"type":"get_step","step":1209}
# {"type":"get_step","step":1210}
# {"type":"get_step","step":1211}
# {"type":"get_step","step":1212}
# {"type":"get_step","step":1213}
# {"type":"get_step","step":1214}
# {"type":"get_step","step":1215}
# {"type":"get_step","step":1216}
# {"type":"get_step","step":1217}
# {"type":"get_step","step":1218}
# {"type":"get_step","step":1219}
# {"type":"get_step","step":1220}
# {"type":"get_step","step":1221}
# {"type":"get_step","step":1222}
# {"type":"get_step","step":1223}
# {"type":"get_step","step":1224}
# {"type":"get_step","step":1225}
# {"type":"get_step","step":1226}
# {"type":"get_step","step":1227}
# {"type":"get_step","step":1228}
# {"type":"get_step","step":1229}
# {"type":"get_step","step":1230}
# {"type":"get_step","step":1231}
# {"type":"get_step","step":1232}
# {"type":"get_step","step":1233}
# {"type":"get_step","step":1234}
# {"type":"get_step","step":1235}
# {"type":"get_step","step":1236}
# {"type":"get_step","step":1237}
# {"type":"get_step","step":1238}
# {"type":"get_step","step":1239}
# {"type":"get_step","step":1240}
# {"type":"get_step","step":1241}
# {"type":"get_step","step":1242}
# {"type":"get_step","step":1243}
# {"type":"get_step","step":1244}
# {"type":"get_step","step":1245}
# {"type":"get_step","step":1246}
# {"type":"get_step","step":1247}
# {"type":"get_step","step":1248}
# {"type":"get_step","step":1249}
# {"type":"get_step","step":1250}
# {"type":"get_step","step":1251}
# {"type":"get_step","step":1252}
# {"type":"get_step","step":1253}
# {"type":"get_step","step":1254}
# {"type":"get_step","step":1255}
# {"type":"get_step","step":1256}
# {"type":"get_step","step":1257}
# {"type":"get_step","step":1258}
# {"type":"get_step","step":1259}
# {"type":"get_step","step":1260}
# {"type":"get_step","step":1261}
# {"type":"get_step","step":1262}
# {"type":"get_step","step":1263}
# {"type":"get_step","step":1264}
# {"type":"get_step","step":1265}
# {"type":"get_step","step":1266}
# {"type":"get_step","step":1267}
# {"type":"get_step","step":1268}
# {"type":"get_step","step":1269}
# {"type":"get_step","step":1270}
# {"type":"get_step","step":1271}
# {"type":"get_step","step":1272}
# {"type":"get_step","step":1273}
# {"type":"get_step","step":1274}
# {"type":"get_step","step":1275}
# {"type":"get_step","step":1276}
# {"type":"get_step","step":1277}
# {"type":"get_step","step":1278}
# {"type":"get_step","step":1279}
# {"type":"get_step","step":1280}
# {"type":"get_step","step":1281}
# {"type":"get_step","step":1282}
# {"type":"get_step","step":1283}
# {"type":"get_step","step":1284}
# {"type":"get_step","step":1285}
# {"type":"get_step","step":1286}
# {"type":"get_step","step":1287}
# {"type":"get_step","step":1288}
# {"type":"get_step","step":1289}
# {"type":"get_step","step":1290}
# {"type":"get_step","step":1291}
# {"type":"get_step","step":1292}
# {"type":"get_step","step":1293}
# {"type":"get_step","step":1294}
# {"type":"get_step","step":1295}
# {"type":"get_step","step":1296}
# {"type":"get_step","step":1297}
# {"type":"get_step","step":1298}
# {"type":"get_step","step":1299}
# {"type":"get_step","step":1300}
# {"type":"get_step","step":1301}
# {"type":"get_step","step":1302}
# {"type":"get_step","step":1303}
# {"type":"get_step","step":1304}
# {"type":"get_step","step":1305}
# {"type":"get_step","step":1306}
# {"type":"get_step","step":1307}
# {"type":"get_step","step":1308}
# {"type":"get_step","step":1309}
# {"type":"get_step","step":1310}
# {"type":"get_step","step":1311}
# {"type":"get_step","step":1312}
# {"type":"get_step","step":1313}
# {"type":"get_step","step":1314}
# {"type":"get_step","step":1315}
# {"type":"get_step","step":1316}

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-29adff364154> in <module>()
# ----> 1 vix[119]
#
# NameError: name 'vix' is not defined

# %%
'''
dj = pd.read_csv('DJIA (Monthly).csv',index_col='DATE', parse_dates=True)
dj = dj[:-1] #Removing last empty row #119 observations
#For some wierd reason know to the excel gods and the Fred people,this has been stored as an object instead of float
#Converting
dj['DJIA'] = dj['DJIA'].apply(pd.to_numeric)
vix = pd.read_csv('vix (Monthly).csv',index_col='DATE', parse_dates=True)
vix = vix[:-1] #Removing last empty row # 120 observations
vix['change']=vix.pct_change(1)
dj['change']= dj.pct_change(1)
vix=vix[1:] #Removing first row #Both have 119 observations now
'''
